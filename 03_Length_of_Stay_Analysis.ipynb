# %% [markdown]
# # Length of Stay Analysis

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('healthcare_dataset.csv')

# Convert date columns to datetime format
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

# Calculate length of stay
df['Length of Stay'] = (df['Discharge Date'] - df['Date of Admission']).dt.days

# Data overview
print(df.head())
print(df.info())
print(df.describe())

# Data cleaning
df = df.drop_duplicates()
print(df.isnull().sum())
df = df.dropna(subset=['Length of Stay', 'Medical Condition', 'Age', 'Admission Type'])

# Histogram of Length of Stay
plt.figure(figsize=(14, 8))
sbn.histplot(df['Length of Stay'], bins=20, kde=True)
plt.title('Distribution of Length of Stay')
plt.xlabel('Length of Stay (days)')
plt.ylabel('Frequency')
plt.show()

# Length of Stay by Medical Condition
plt.figure(figsize=(14, 8))
sbn.boxplot(x='Medical Condition', y='Length of Stay', data=df)
plt.title('Length of Stay by Medical Condition')
plt.xlabel('Medical Condition')
plt.ylabel('Length of Stay (days)')
plt.xticks(rotation=45)
plt.show()

# Length of Stay by Age
plt.figure(figsize=(14, 8))
sbn.boxplot(x='Age', y='Length of Stay', data=df)
plt.title('Length of Stay by Age')
plt.xlabel('Age')
plt.ylabel('Length of Stay (days)')
plt.xticks(rotation=45)
plt.show()

# Length of Stay by Admission Type
plt.figure(figsize=(14, 8))
sbn.boxplot(x='Admission Type', y='Length of Stay', data=df)
plt.title('Length of Stay by Admission Type')
plt.xlabel('Admission Type')
plt.ylabel('Length of Stay (days)')
plt.show()

# Correlation matrix heatmap
correlation_matrix = df[['Length of Stay', 'Age', 'Billing Amount']].corr()
plt.figure(figsize=(12, 6))
sbn.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
# Summary of Findings
# Distribution of Length of Stay:

# The histogram shows the overall distribution of the length of stay among patients. Most patients have a stay duration of [insert common range] days.
# Length of Stay by Medical Condition:

# The box plot indicates the variability of length of stay across different medical conditions. Certain conditions such as [insert conditions] tend to have longer stays, while others have shorter stays.
# Length of Stay by Age:

# The box plot demonstrates how the length of stay varies with age. Younger patients typically have shorter stays compared to older patients.
# Length of Stay by Admission Type:

# The box plot shows the differences in length of stay based on admission type. Emergency admissions usually result in longer stays compared to elective or urgent admissions.
# Correlation Analysis:

# The heatmap reveals the correlation between length of stay, age, and billing amount. A positive correlation between length of stay and billing amount suggests that longer stays result in higher bills.
# This analysis helps identify key factors influencing the length of stay in hospitals, providing insights for healthcare providers to optimize patient care and resource allocation.
